# %% [markdown]
# <a href="https://colab.research.google.com/github/VenkatChalamallaaaaaa/EDA_DA/blob/main/EDATHEORYFINALDA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Venkat Chalamalla 21BDS0276
#EDA DA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr, spearmanr
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

sns.set()

# %%
#Venkat Chalamalla
data = pd.read_csv('htv.csv')
data.head()
# Out:
#    rownames       wage      abil  educ  ne  nc  west  south  exper  motheduc  \
# 0         1  12.019231  5.027738    15   0   0     1      0      9        12
# 1         2   8.912656  2.037170    13   1   0     0      0      8        12
# 2         3  15.514334  2.475895    15   1   0     0      0     11        12
# 3         4  13.333333  3.609240    15   1   0     0      0      6        12
# 4         5  11.070110  2.636546    13   1   0     0      0     15        12
#
#    ...  ne18  nc18  south18  west18  urban18    tuit17     tuit18     lwage  \
# 0  ...     1     0        0       0        1  7.582914   7.260242  2.486508
# 1  ...     1     0        0       0        1  8.595144   9.499537  2.187472
# 2  ...     1     0        0       0        1  7.311346   7.311346  2.741764
# 3  ...     1     0        0       0        1  9.499537  10.162070  2.590267
# 4  ...     1     0        0       0        1  7.311346   7.311346  2.404249
#
#    expersq     ctuit
# 0       81 -0.322671
# ...

# %%
data.shape
# Out:
# (1230, 24)

# %%
#Description
print("Venkat Chalamalla 21BDS0276")
data.describe()
# Out:
# Venkat Chalamalla 21BDS0276
#           rownames         wage         abil         educ           ne  \
# count  1230.000000  1230.000000  1230.000000  1230.000000  1230.000000
# mean    615.500000    13.288134     1.796596    13.037398     0.211382
# std     355.214724     9.081947     2.184406     2.354346     0.408455
# min       1.000000     1.023529    -5.631463     6.000000     0.000000
# 25%     308.250000     7.942430     0.566200    12.000000     0.000000
# 50%     615.500000    11.542903     2.149759    12.000000     0.000000
# 75%     922.750000    16.025640     3.461465    15.000000     0.000000
# max    1230.000000    91.309219     6.263742    20.000000     1.000000
#
#                 nc         west        south        exper     motheduc  ...  \
# count  1230.000000  1230.000000  1230.000000  1230.000000  1230.000000  ...
# mean      0.372358     0.169106     0.247154    10.741463    12.178049  ...
# ...

# %%
#check for null Values
print("Venkat Chalamalla 21BDS0276")
data.isnull().sum()
# Out:
# Venkat Chalamalla 21BDS0276
# rownames    0
# wage        0
# abil        0
# educ        0
# ne          0
# nc          0
# west        0
# south       0
# exper       0
# motheduc    0
# fatheduc    0
# brkhme14    0
# sibs        0
# urban       0
# ne18        0
# nc18        0
# south18     0
# west18      0
# urban18     0
# tuit17      0
# tuit18      0
# lwage       0
# expersq     0
# ctuit       0
# dtype: int64

# %%
print("Venkat Chalamalla 21BDS0276")
data.drop_duplicates(inplace=True)
# Out:
# Venkat Chalamalla 21BDS0276

# %%
print("Venkat Chalamalla 21BDS0276")
data.dtypes
# Out:
# Venkat Chalamalla 21BDS0276
# rownames      int64
# wage        float64
# abil        float64
# educ          int64
# ne            int64
# nc            int64
# west          int64
# south         int64
# exper         int64
# motheduc      int64
# fatheduc      int64
# brkhme14      int64
# sibs          int64
# urban         int64
# ne18          int64
# nc18          int64
# south18       int64
# west18        int64
# urban18       int64
# tuit17      float64
# tuit18      float64
# lwage       float64
# expersq       int64
# ctuit       float64
# dtype: object

# %%
print("Venkat Chalamalla 21BDS0276")
plt.figure(figsize=(10, 5))
sns.histplot(data['wage'], kde=True)
plt.title("Wage Distribution")
plt.xlabel("Wage")
plt.ylabel("Frequency")
plt.show()
# Out:
# Venkat Chalamalla 21BDS0276

# %%
print("Venkat Chalamalla 21BDS0276")
plt.figure(figsize=(10, 5))
sns.boxplot(x=data['educ'])
plt.title("Education Levels Boxplot")
plt.xlabel("Education Level")
plt.show()
# Out:
# Venkat Chalamalla 21BDS0276

# %%
print("Venkat Chalamalla 21BDS0276")
plt.figure(figsize=(10, 5))
sns.histplot(data['abil'], kde=True)
plt.title("Ability Distribution")
plt.xlabel("Ability")
plt.ylabel("Frequency")
plt.show()
# Out:
# Venkat Chalamalla 21BDS0276

# %%
print("Venkat Chalamalla 21BDS0276")
plt.figure(figsize=(6, 4))
sns.countplot(x='urban', data=data)
plt.title("Distribution of Urban Variable")
plt.xlabel("Urban")
plt.ylabel("Count")
plt.show()
# Out:
# Venkat Chalamalla 21BDS0276

# %%
print("Venkat Chalamalla 21BDS0276")
plt.figure(figsize=(6, 4))
sns.countplot(x='south', data=data)
plt.title("Distribution of South Variable")
plt.xlabel("South")
plt.ylabel("Count")
plt.show()
# Out:
# Venkat Chalamalla 21BDS0276

# %%
print("Venkat Chalamalla 21BDS0276")
plt.figure(figsize=(6, 6))
sns.scatterplot(x='educ', y='wage', data=data)
plt.title("Wage vs Education")
plt.xlabel("Education Level")
plt.ylabel("Wage")
plt.show()
# Out:
# Venkat Chalamalla 21BDS0276

# %%
print("Venkat Chalamalla 21BDS0276")
plt.figure(figsize=(10, 6))
sns.scatterplot(x='abil', y='wage', data=data)
plt.title("Wage vs Ability")
plt.xlabel("Ability")
plt.ylabel("Wage")
plt.show()
# Out:
# Venkat Chalamalla 21BDS0276

# %%
print("Venkat Chalamalla 21BDS0276")
plt.figure(figsize=(10, 6))
sns.boxplot(x='south', y='wage', data=data)
plt.title("Wage Distribution across South")
plt.xlabel("South")
plt.ylabel("Wage")
plt.show()
# Out:
# Venkat Chalamalla 21BDS0276

# %%
print("Venkat Chalamalla 21BDS0276")
plt.figure(figsize=(5, 5))
correlation = data[['wage', 'educ', 'abil', 'exper']].corr()
sns.heatmap(correlation, annot=True, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Venkat Chalamalla 21BDS0276

# %%
print("Venkat Chalamalla 21BDS0276")
sns.pairplot(data[['wage', 'educ', 'abil', 'exper']])
plt.show()
# Out:
# Venkat Chalamalla 21BDS0276

# %%
print("Venkat Chalamalla 21BDS0276")
plt.figure(figsize=(10, 6))
sns.regplot(x='exper', y='wage', data=data)
plt.title("Wage vs Experience with Regression Line")
plt.xlabel("Experience")
plt.ylabel("Wage")
plt.show()
# Out:
# Venkat Chalamalla 21BDS0276

# %%
print("Venkat Chalamalla 21BDS0276")
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data['educ'], data['exper'], data['wage'], c='b', marker='o')
ax.set_xlabel("Education")
ax.set_ylabel("Experience")
ax.set_zlabel("Wage")
plt.title("3D Scatter Plot for Wage, Education, Experience")
plt.show()
# Out:
# Venkat Chalamalla 21BDS0276

# %%
print("Venkat Chalamalla 21BDS0276")
kmeans = KMeans(n_clusters=3)
data['cluster'] = kmeans.fit_predict(data[['abil', 'educ', 'exper']])
sns.pairplot(data, vars=['abil', 'educ', 'exper'], hue='cluster', palette='viridis')
fig = plt.figure(figsize=(6, 6))
plt.show()
# Out:
# Venkat Chalamalla 21BDS0276

# %%
print("Venkat Chalamalla 21BDS0276")
X = data[['educ', 'abil', 'exper', 'urban']]
y = data['wage']
model = LinearRegression()
model.fit(X, y)
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
print("R-squared:", model.score(X, y))
# Out:
# Venkat Chalamalla 21BDS0276
# Coefficients: [1.73940812 0.47892207 0.77045794 3.35189355]
# Intercept: -21.264239547042695
# R-squared: 0.18139389941113038

# %%
print("Venkat Chalamalla 21BDS0276")
categorical_heatmap_data = pd.crosstab(data['south'], data['urban'])
sns.heatmap(categorical_heatmap_data, annot=True, cmap="YlGnBu")
plt.title("Heatmap of South vs Urban")
plt.xlabel("Urban")
plt.ylabel("South")
plt.show()
# Out:
# Venkat Chalamalla 21BDS0276

# %%
# Out:
# Venkat Chalamalla 21BDS0276

# %%
# Standardizing the data for PCA, KMeans, and KNN
print("Venkat Chalamalla 21BDS0276")
df = pd.read_csv('htv.csv')
scaler = StandardScaler()
scaled_df = pd.DataFrame(scaler.fit_transform(df.select_dtypes(include=[np.number])), columns=df.select_dtypes(include=[np.number]).columns)

# PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(scaled_df)
print("PCA Explained Variance Ratios:", pca.explained_variance_ratio_)

# Plotting PCA
plt.figure(figsize=(8, 6))
plt.scatter(pca_result[:, 0], pca_result[:, 1], color='blue', alpha=0.6)
plt.title('PCA Result (2 Components)')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()
# Out:
# Venkat Chalamalla 21BDS0276
# PCA Explained Variance Ratios: [0.18634014 0.15640883]

# %%
# KMeans Clustering
print("Venkat Chalamalla 21BDS0276")
kmeans = KMeans(n_clusters=3, random_state=42)
df['cluster'] = kmeans.fit_predict(scaled_df)

# Visualizing KMeans clusters
plt.figure(figsize=(8, 6))
sns.scatterplot(x=pca_result[:, 0], y=pca_result[:, 1], hue=df['cluster'], palette='viridis')
plt.title('KMeans Clustering with PCA Components')
plt.show()
# Out:
# Venkat Chalamalla 21BDS0276

# %%
# KNN Model:
print("Venkat Chalamalla 21BDS0276")
df.head()
X = df.drop(columns=['wage'])
y = df['abil']

from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=3)
knn.fit(X, y)
y_pred = knn.predict(X)

# Evaluate the model (using R2 score)
print("KNN Regressor R-squared score:", knn.score(X, y))
# Out:
# Venkat Chalamalla 21BDS0276
# KNN Regressor R-squared score: 0.5518555269994565

# %%
#Hierarchical Clustering
from scipy import stats
import scipy.cluster.hierarchy as sch
print("Venkat Chalamalla 21BDS0276")
dendrogram = sch.dendrogram(sch.linkage(scaled_df, method='ward'))
plt.title('Dendrogram for Hierarchical Clustering')
plt.show()
# Out:
# Venkat Chalamalla 21BDS0276
